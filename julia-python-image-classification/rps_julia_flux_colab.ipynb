# %%
# script source --> https://colab.research.google.com/github/ageron/julia_notebooks/blob/master/Julia_Colab_Notebook_Template.ipynb

%%shell
set -e

#---------------------------------------------------#
JULIA_VERSION="1.8.3" # any version ≥ 0.7.0
JULIA_PACKAGES="IJulia"
JULIA_PACKAGES_IF_GPU="CUDA" # or CuArrays for older Julia versions
JULIA_NUM_THREADS=2
#---------------------------------------------------#

if [ -z `which julia` ]; then
  # Install Julia
  JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
  echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
  BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
  URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
  wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
  tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
  rm /tmp/julia.tar.gz

  # Install Packages
  nvidia-smi -L &> /dev/null && export GPU=1 || export GPU=0
  if [ $GPU -eq 1 ]; then
    JULIA_PACKAGES="$JULIA_PACKAGES $JULIA_PACKAGES_IF_GPU"
  fi
  for PKG in `echo $JULIA_PACKAGES`; do
    echo "Installing Julia package $PKG..."
    julia -e 'using Pkg; pkg"add '$PKG'; precompile;"' &> /dev/null
  done

  # Install kernel and rename it to "julia"
  echo "Installing IJulia kernel..."
  julia -e 'using IJulia; IJulia.installkernel("julia", env=Dict(
      "JULIA_NUM_THREADS"=>"'"$JULIA_NUM_THREADS"'"))'
  KERNEL_DIR=`julia -e "using IJulia; print(IJulia.kerneldir())"`
  KERNEL_NAME=`ls -d "$KERNEL_DIR"/julia*`
  mv -f $KERNEL_NAME "$KERNEL_DIR"/julia  

  echo ''
  echo "Successfully installed `julia -v`!"
  echo "Please reload this page (press Ctrl+R, ⌘+R, or the F5 key) then"
  echo "jump to the 'Checking the Installation' section."
fi
# Out:
# Installing Julia 1.8.3 on the current Colab Runtime...
# 2022-11-27 12:26:34 URL:https://julialang-s3.julialang.org/bin/linux/x64/1.8/julia-1.8.3-linux-x86_64.tar.gz [130030846/130030846] -> "/tmp/julia.tar.gz" [1]
# Installing Julia package IJulia...
# Installing Julia package CUDA...
# Installing IJulia kernel...
# [ Info: Installing julia kernelspec in /root/.local/share/jupyter/kernels/julia-1.8
#
# Successfully installed julia version 1.8.3!
# Please reload this page (press Ctrl+R, ⌘+R, or the F5 key) then
# jump to the 'Checking the Installation' section.

# %% [markdown]
# # Check Julia Version

# %%
versioninfo()
# Out:
# Julia Version 1.8.3
# Commit 0434deb161e (2022-11-14 20:14 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 2 × Intel(R) Xeon(R) CPU @ 2.00GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, skylake-avx512)
#   Threads: 2 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/lib64-nvidia
#   LD_PRELOAD = /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4
#   JULIA_NUM_THREADS = 2

# %% [markdown]
# # Install required packages

# %%
using Pkg
Pkg.add(["ZipFile", "Random", "Augmentor", "Images", "MLUtils", "Flux", "ImageCore", "OneHotArrays"])
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed JpegTurbo_jll ─────────────── v2.1.2+0
#    Installed ImageIO ───────────────────── v0.4.1
#    Installed TiledIteration ────────────── v0.3.1
#    Installed OffsetArrays ──────────────── v1.12.8
#    Installed ContextVariablesX ─────────── v0.1.3
#    Installed AxisArrays ────────────────── v0.4.6
#    Installed ShowCases ─────────────────── v0.1.0
#    Installed PNGFiles ──────────────────── v0.3.17
#    Installed LERC_jll ──────────────────── v3.0.0+1
#    Installed FFTW ──────────────────────── v1.5.0
#    Installed Accessors ─────────────────── v0.1.22
#    Installed ImageMagick ───────────────── v1.2.2
#    Installed NNlib ─────────────────────── v0.8.10
#    Installed ZipFile ───────────────────── v0.10.1
#    Installed NNlibCUDA ─────────────────── v0.2.4
#    Installed StaticArrays ──────────────── v1.5.10
#    Installed Optimisers ────────────────── v0.2.12
#    Installed Images ────────────────────── v0.24.1
#    Installed InitialValues ─────────────── v0.3.1
#    Installed IdentityRanges ────────────── v0.3.1
#    Installed FunctionWrappers ──────────── v1.1.3
#    Installed IntelOpenMP_jll ───────────── v2018.0.3+2
#    Installed FileIO ────────────────────── v1.16.0
#    Installed Netpbm ────────────────────── v1.0.1
#    Installed ZygoteRules ───────────────── v0.2.2
#    Installed PrettyPrint ───────────────── v0.2.0
#    Installed Distances ─────────────────── v0.10.7
#    Installed MLUtils ───────────────────── v0.3.1
#    Installed RealDot ───────────────────── v0.1.0
#    Installed Missings ──────────────────── v1.0.2
#    Installed FLoopsBase ────────────────── v0.1.1
#    Installed ProgressLogging ───────────── v0.1.4
#    Installed Functors ──────────────────── v0.3.0
#    Installed IRTools ───────────────────── v0.4.7
#    Installed Augmentor ─────────────────── v0.6.6
#    Installed StaticArraysCore ──────────── v1.4.0
#    Installed NaNMath ───────────────────── v1.0.1
#    Installed DefineSingletons ──────────── v0.1.2
#    Installed MicroCollections ──────────── v0.1.3
#    Installed NameResolution ────────────── v0.1.5
#    Installed OneHotArrays ──────────────── v0.2.0
#    Installed Zygote ────────────────────── v0.6.49
#    Installed ImageContrastAdjustment ───── v0.3.7
#    Installed CustomUnitRanges ──────────── v1.0.2
#    Installed ImageMetadata ─────────────── v0.9.5
#    Installed Ratios ────────────────────── v0.4.3
#    Installed Graphics ──────────────────── v1.1.2
#    Installed DataStructures ────────────── v0.18.13
#    Installed Colors ────────────────────── v0.12.8
#    Installed ChainRules ────────────────── v1.45.0
#    Installed CatIndices ────────────────── v0.2.2
#    Installed MappedArrays ──────────────── v0.4.1
#    Installed CommonSubexpressions ──────── v0.3.0
#    Installed ComputationalResources ────── v0.3.2
#    Installed ImageMagick_jll ───────────── v6.9.10-12+3
#    Installed PaddedViews ───────────────── v0.5.11
#    Installed StatsAPI ──────────────────── v1.5.0
#    Installed ImageTransformations ──────── v0.8.13
#    Installed BangBang ──────────────────── v0.3.37
#    Installed ImageFiltering ────────────── v0.6.21
#    Installed FLoops ────────────────────── v0.2.1
#    Installed MLStyle ───────────────────── v0.4.16
#    Installed libpng_jll ────────────────── v1.6.38+0
#    Installed MosaicViews ───────────────── v0.3.4
#    Installed StatsBase ─────────────────── v0.33.21
#    Installed ImageCore ─────────────────── v0.8.22
#    Installed ColorTypes ────────────────── v0.11.4
#    Installed Zstd_jll ──────────────────── v1.5.2+0
#    Installed ArgCheck ──────────────────── v2.3.0
#    Installed DiffRules ─────────────────── v1.12.2
#    Installed TensorCore ────────────────── v0.1.1
#    Installed TableTraits ───────────────── v1.0.1
#    Installed DiffResults ───────────────── v1.1.0
#    Installed ImageShow ─────────────────── v0.3.1
#    Installed Flux ──────────────────────── v0.13.8
#    Installed MKL_jll ───────────────────── v2022.2.0+0
#    Installed Libtiff_jll ───────────────── v4.4.0+0
#    Installed ImageQualityIndexes ───────── v0.2.2
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed ColorVectorSpace ──────────── v0.9.9
#    Installed ConstructionBase ──────────── v1.4.1
#    Installed Setfield ──────────────────── v1.1.1
#    Installed OrderedCollections ────────── v1.4.1
#    Installed RangeArrays ───────────────── v0.3.2
#    Installed FFTW_jll ──────────────────── v3.3.10+0
#    Installed MacroTools ────────────────── v0.5.10
#    Installed Rotations ─────────────────── v1.3.3
#    Installed Quaternions ───────────────── v0.6.1
#    Installed StackViews ────────────────── v0.1.1
#    Installed CompositionsBase ──────────── v0.1.1
#    Installed UnPack ────────────────────── v1.0.2
#    Installed CoordinateTransformations ─── v0.6.2
#    Installed JuliaVariables ────────────── v0.2.4
#    Installed SimpleTraits ──────────────── v0.9.4
#    Installed IntervalSets ──────────────── v0.7.3
#    Installed IndirectArrays ────────────── v0.5.1
#    Installed DataAPI ───────────────────── v1.13.0
#    Installed IterTools ─────────────────── v1.4.0
#    Installed FoldsThreads ──────────────── v0.1.1
#    Installed Tables ────────────────────── v1.10.0
#    Installed Transducers ───────────────── v0.4.75
#    Installed Baselet ───────────────────── v0.1.1
#    Installed ImageDistances ────────────── v0.2.13
#    Installed FixedPointNumbers ─────────── v0.8.4
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed StructArrays ──────────────── v0.6.13
#    Installed FillArrays ────────────────── v0.13.5
#    Installed ForwardDiff ───────────────── v0.10.33
#    Installed AxisAlgorithms ────────────── v1.0.1
#    Installed LearnBase ─────────────────── v0.4.1
#    Installed ImageAxes ─────────────────── v0.6.9
#    Installed FFTViews ──────────────────── v0.3.2
#    Installed SplittablesBase ───────────── v0.1.15
#    Installed Parameters ────────────────── v0.12.3
#    Installed MLDataPattern ─────────────── v0.5.5
#    Installed Interpolations ────────────── v0.13.6
#    Installed ImageMorphology ───────────── v0.2.11
#    Installed WoodburyMatrices ──────────── v0.5.5
#    Installed SortingAlgorithms ─────────── v1.1.0
#    Installed MLLabelUtils ──────────────── v0.5.7
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [02898b10] + Augmentor v0.6.6
#   [587475ba] + Flux v0.13.8
# ⌅ [a09fc81d] + ImageCore v0.8.22
# ⌃ [916415d5] + Images v0.24.1
#   [f1d291b0] + MLUtils v0.3.1
#   [0b1bfda6] + OneHotArrays v0.2.0
#   [a5390f91] + ZipFile v0.10.1
#   [9a3f8284] + Random
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [7d9f7c33] + Accessors v0.1.22
#   [dce04be8] + ArgCheck v2.3.0
#   [02898b10] + Augmentor v0.6.6
#   [13072b0f] + AxisAlgorithms v1.0.1
#   [39de3d68] + AxisArrays v0.4.6
#   [198e06fe] + BangBang v0.3.37
#   [9718e550] + Baselet v0.1.1
#   [aafaddc9] + CatIndices v0.2.2
#   [082447d4] + ChainRules v1.45.0
#   [3da002f7] + ColorTypes v0.11.4
#   [c3611d14] + ColorVectorSpace v0.9.9
#   [5ae59095] + Colors v0.12.8
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [a33af91c] + CompositionsBase v0.1.1
#   [ed09eef8] + ComputationalResources v0.3.2
#   [187b0558] + ConstructionBase v1.4.1
#   [6add18c4] + ContextVariablesX v0.1.3
#   [150eb455] + CoordinateTransformations v0.6.2
#   [dc8bdbbb] + CustomUnitRanges v1.0.2
#   [9a962f9c] + DataAPI v1.13.0
#   [864edb3b] + DataStructures v0.18.13
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [244e2a9f] + DefineSingletons v0.1.2
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.12.2
#   [b4f34e82] + Distances v0.10.7
#   [4f61f5a4] + FFTViews v0.3.2
#   [7a1cc6ca] + FFTW v1.5.0
#   [cc61a311] + FLoops v0.2.1
#   [b9860ae5] + FLoopsBase v0.1.1
#   [5789e2e9] + FileIO v1.16.0
#   [1a297f60] + FillArrays v0.13.5
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [587475ba] + Flux v0.13.8
#   [9c68100b] + FoldsThreads v0.1.1
#   [f6369f11] + ForwardDiff v0.10.33
#   [069b7b12] + FunctionWrappers v1.1.3
#   [d9f16b24] + Functors v0.3.0
#   [a2bd30eb] + Graphics v1.1.2
#   [7869d1d1] + IRTools v0.4.7
#   [bbac6d45] + IdentityRanges v0.3.1
# ⌃ [2803e5a7] + ImageAxes v0.6.9
# ⌃ [f332f351] + ImageContrastAdjustment v0.3.7
# ⌅ [a09fc81d] + ImageCore v0.8.22
# ⌃ [51556ac3] + ImageDistances v0.2.13
# ⌅ [6a3955dd] + ImageFiltering v0.6.21
# ⌅ [82e4d734] + ImageIO v0.4.1
#   [6218d12a] + ImageMagick v1.2.2
# ⌃ [bc367c6b] + ImageMetadata v0.9.5
# ⌅ [787d08f9] + ImageMorphology v0.2.11
# ⌅ [2996bd0c] + ImageQualityIndexes v0.2.2
# ⌃ [4e3cecfd] + ImageShow v0.3.1
# ⌅ [02fcd773] + ImageTransformations v0.8.13
# ⌃ [916415d5] + Images v0.24.1
# ⌅ [9b13fd28] + IndirectArrays v0.5.1
#   [22cec73e] + InitialValues v0.3.1
# ⌅ [a98d9a8b] + Interpolations v0.13.6
#   [8197267c] + IntervalSets v0.7.3
#   [c8e1da08] + IterTools v1.4.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [b14d175d] + JuliaVariables v0.2.4
# ⌅ [7f8f8fb0] + LearnBase v0.4.1
#   [9920b226] + MLDataPattern v0.5.5
#   [66a33bbf] + MLLabelUtils v0.5.7
#   [d8e11817] + MLStyle v0.4.16
#   [f1d291b0] + MLUtils v0.3.1
#   [1914dd2f] + MacroTools v0.5.10
#   [dbb5928d] + MappedArrays v0.4.1
#   [128add7d] + MicroCollections v0.1.3
#   [e1d29d7a] + Missings v1.0.2
#   [e94cdb99] + MosaicViews v0.3.4
#   [872c559c] + NNlib v0.8.10
#   [a00861dc] + NNlibCUDA v0.2.4
#   [77ba4419] + NaNMath v1.0.1
#   [71a1bf82] + NameResolution v0.1.5
# ⌃ [f09324ee] + Netpbm v1.0.1
#   [6fe1bfb0] + OffsetArrays v1.12.8
#   [0b1bfda6] + OneHotArrays v0.2.0
#   [3bd65402] + Optimisers v0.2.12
#   [bac558e1] + OrderedCollections v1.4.1
#   [f57f5aa1] + PNGFiles v0.3.17
#   [5432bcbf] + PaddedViews v0.5.11
#   [d96e819e] + Parameters v0.12.3
#   [8162dcfd] + PrettyPrint v0.2.0
#   [33c8b6b6] + ProgressLogging v0.1.4
#   [94ee1d12] + Quaternions v0.6.1
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.3
#   [c1ae055f] + RealDot v0.1.0
#   [6038ab10] + Rotations v1.3.3
#   [efcf1570] + Setfield v1.1.1
#   [605ecd9f] + ShowCases v0.1.0
#   [699a6c99] + SimpleTraits v0.9.4
#   [a2af1166] + SortingAlgorithms v1.1.0
#   [171d559e] + SplittablesBase v0.1.15
#   [cae243ae] + StackViews v0.1.1
#   [90137ffa] + StaticArrays v1.5.10
#   [1e83bf80] + StaticArraysCore v1.4.0
#   [82ae8749] + StatsAPI v1.5.0
#   [2913bbd2] + StatsBase v0.33.21
#   [09ab397b] + StructArrays v0.6.13
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.10.0
#   [62fd8b95] + TensorCore v0.1.1
# ⌅ [06e1c1a7] + TiledIteration v0.3.1
#   [28d57a85] + Transducers v0.4.75
#   [3a884ed6] + UnPack v1.0.2
#   [efce3f68] + WoodburyMatrices v0.5.5
#   [a5390f91] + ZipFile v0.10.1
#   [e88e6eb3] + Zygote v0.6.49
#   [700de1a5] + ZygoteRules v0.2.2
#   [f5851436] + FFTW_jll v3.3.10+0
# ⌅ [c73af94c] + ImageMagick_jll v6.9.10-12+3
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [aacddb02] + JpegTurbo_jll v2.1.2+0
#   [88015f11] + LERC_jll v3.0.0+1
#   [89763e89] + Libtiff_jll v4.4.0+0
#   [856f044c] + MKL_jll v2022.2.0+0
#   [3161d3a3] + Zstd_jll v1.5.2+0
#   [b53b4c65] + libpng_jll v1.6.38+0
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [1a1011a3] + SharedArrays
#         Info Packages marked with ⌃ and ⌅ have new versions available, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ RangeArrays
#   ✓ IndirectArrays
#   ✓ IteratorInterfaceExtensions
#   ✓ TensorCore
#   ✓ FunctionWrappers
#   ✓ StatsAPI
#   ✓ Quaternions
#   ✓ LearnBase
#   ✓ InitialValues
#   ✓ UnPack
#   ✓ PrettyPrint
#   ✓ ArgCheck
#   ✓ FillArrays
#   ✓ FixedPointNumbers
#   ✓ WoodburyMatrices
#   ✓ ShowCases
#   ✓ IterTools
#   ✓ OrderedCollections
#   ✓ RealDot
#   ✓ DataValueInterfaces
#   ✓ CustomUnitRanges
#   ✓ IntervalSets
#   ✓ CompositionsBase
#   ✓ DefineSingletons
#   ✓ NaNMath
#   ✓ MacroTools
#   ✓ Ratios
#   ✓ ContextVariablesX
#   ✓ ConstructionBase
#   ✓ DataAPI
#   ✓ ProgressLogging
#   ✓ ComputationalResources
#   ✓ StaticArraysCore
#   ✓ Functors
#   ✓ MappedArrays
#   ✓ Baselet
#   ✓ ZipFile
#   ✓ FileIO
#   ✓ OffsetArrays
#   ✓ libpng_jll
#   ✓ IntelOpenMP_jll
#   ✓ LERC_jll
#   ✓ JpegTurbo_jll
#   ✓ Zstd_jll
#   ✓ NNlib
#   ✓ TableTraits
#   ✓ FFTW_jll
#   ✓ NameResolution
#   ✓ Distances
#   ✓ AxisAlgorithms
#   ✓ ColorTypes
#   ✓ Parameters
#   ✓ DataStructures
#   ✓ DiffRules
#   ✓ AxisArrays
#   ✓ CommonSubexpressions
#   ✓ MLStyle
#   ✓ ZygoteRules
#   ✓ FLoopsBase
#   ✓ SimpleTraits
#   ✓ Missings
#   ✓ IRTools
#   ✓ DiffResults
#   ✓ Accessors
#   ✓ Setfield
#   ✓ Optimisers
#   ✓ TiledIteration
#   ✓ CatIndices
#   ✓ StackViews
#   ✓ IdentityRanges
#   ✓ PaddedViews
#   ✓ MKL_jll
#   ✓ Libtiff_jll
#   ✓ Tables
#   ✓ ColorVectorSpace
#   ✓ StaticArrays
#   ✓ SortingAlgorithms
#   ✓ NNlibCUDA
#   ✓ SplittablesBase
#   ✓ Colors
#   ✓ MosaicViews
#   ✓ JuliaVariables
#   ✓ ImageMagick_jll
#   ✓ StructArrays
#   ✓ BangBang
#   ✓ CoordinateTransformations
#   ✓ FFTW
#   ✓ Rotations
#   ✓ Interpolations
#   ✓ StatsBase
#   ✓ Graphics
#   ✓ MicroCollections
#   ✓ ForwardDiff
#   ✓ MLLabelUtils
#   ✓ FFTViews
#   ✓ Transducers
#   ✓ ChainRules
#   ✓ MLDataPattern
#   ✓ ImageCore
#   ✓ FoldsThreads
#   ✓ ImageAxes
#   ✓ ImageMorphology
#   ✓ FLoops
#   ✓ ImageShow
#   ✓ Zygote
#   ✓ Netpbm
#   ✓ ImageMagick
#   ✓ PNGFiles
#   ✓ ImageTransformations
#   ✓ ImageMetadata
#   ✓ ImageDistances
#   ✓ ImageIO
#   ✓ ImageContrastAdjustment
#   ✓ MLUtils
#   ✓ OneHotArrays
#   ✓ ImageFiltering
#   ✓ ImageQualityIndexes
#   ✓ Augmentor
#   ✓ Images
#   ✓ Flux
#   120 dependencies successfully precompiled in 151 seconds. 45 already precompiled.

# %% [markdown]
# # Set random seed

# %%
using Random
seed = 12
Random.Random.seed!(seed)
# Out:
# TaskLocalRNG()

# %% [markdown]
# # Download and extract image files to local storage

# %%
download("https://github.com/thetestspecimen/notebooks/raw/main/datasets/rock_paper_scissors/rock_paper_scissors.zip","./rock_paper_scissors.zip")
# Out:
# "./rock_paper_scissors.zip"

# %% [markdown]
# The following function unzips the image files into a folder structure.
#
# Source code for this function (with a minor adjustment to check subfolders): https://github.com/sylvaticus/LAJuliaUtils.jl

# %%
using ZipFile
function unzip_file(file,exdir="")
    fileFullPath = isabspath(file) ?  file : joinpath(pwd(),file)
    basePath = dirname(fileFullPath)
    outPath = (exdir == "" ? basePath : (isabspath(exdir) ? exdir : joinpath(pwd(),exdir)))
    isdir(outPath) || mkdir(outPath)
    zarchive = ZipFile.Reader(fileFullPath)
    for f in zarchive.files
        fullFilePath = joinpath(outPath,f.name)
        if (endswith(f.name,"/") || endswith(f.name,"\\"))
            isdir(fullFilePath) ||  mkdir(fullFilePath)
        else
            write(fullFilePath, read(f))
        end
    end
    close(zarchive)
end
# Out:
# unzip_file (generic function with 2 methods)

# %%
root_folder = "rps"
unzip_file("rock_paper_scissors.zip", root_folder)

# %% [markdown]
# # A view of the new directory structure and files

# %%
for (root, dirs, files) in walkdir(root_folder)
    println("$(length(dirs)) directories and $(length(files)) files in $root")
end
# Out:
# 3 directories and 0 files in rps
# 0 directories and 200 files in rps/paper
# 0 directories and 200 files in rps/rock
# 0 directories and 200 files in rps/scissors

# %%
readdir(root_folder)
# Out:
# 3-element Vector{String}:
#  "paper"
#  "rock"
#  "scissors"

# %% [markdown]
# # Plot an example image from each class

# %%
using Images, ImageCore
function plot_example_image(root_f, target_class)
    # target directory
    target_folder = "$(root_f)/$(target_class)/"
    # random image
    image_name = Random.rand(readdir(target_folder))
    # plot image
    img = Images.load(string(target_folder, image_name))
    img_channels = ImageCore.channelview(float32.(img))
    println("Type: ", typeof(img))
    println("Shape: ", size(img))
    println("Colour channels: ", size(img_channels)[1])
    println("Size: ", sizeof(img)/1000," KB")
    println("Max: ", maximum(img_channels))
    println("Min: ", minimum(img_channels))
    println("Image name: ", image_name)
    println("Class: ", target_class)
    return img
end
# Out:
# plot_example_image (generic function with 1 method)

# %%
plot_example_image(root_folder,"rock")
# Out:
# Type: Matrix{RGB{N0f8}}
# Shape: (200, 300)
# Colour channels: 3
# Size: 180.0 KB
# Max: 0.96862745
# Min: 0.0
# Image name: BnnRzew7yA30gyts.png
# Class: rock
# 200×300 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.122,0.447,0.149)  …  RGB{N0f8}(0.133,0.459,0.153)
#  RGB{N0f8}(0.102,0.443,0.141)     RGB{N0f8}(0.122,0.455,0.149)
#  RGB{N0f8}(0.106,0.447,0.145)     RGB{N0f8}(0.125,0.459,0.153)
#  RGB{N0f8}(0.114,0.459,0.157)     RGB{N0f8}(0.122,0.455,0.149)
#  RGB{N0f8}(0.114,0.459,0.157)     RGB{N0f8}(0.137,0.471,0.161)
#  RGB{N0f8}(0.114,0.459,0.157)  …  RGB{N0f8}(0.125,0.467,0.165)
#  RGB{N0f8}(0.122,0.463,0.161)     RGB{N0f8}(0.125,0.467,0.165)
#  RGB{N0f8}(0.114,0.459,0.157)     RGB{N0f8}(0.125,0.467,0.165)
#  RGB{N0f8}(0.106,0.447,0.145)     RGB{N0f8}(0.122,0.463,0.161)
#  RGB{N0f8}(0.11,0.459,0.157)      RGB{N0f8}(0.114,0.475,0.157)
#  RGB{N0f8}(0.098,0.451,0.145)  …  RGB{N0f8}(0.118,0.478,0.161)
#  RGB{N0f8}(0.106,0.455,0.157)     RGB{N0f8}(0.122,0.475,0.161)
#  RGB{N0f8}(0.11,0.459,0.165)      RGB{N0f8}(0.122,0.475,0.161)
#  ⋮                             ⋱
#  RGB{N0f8}(0.094,0.482,0.173)     RGB{N0f8}(0.118,0.49,0.184)
#  RGB{N0f8}(0.098,0.478,0.165)     RGB{N0f8}(0.118,0.486,0.196)
#  RGB{N0f8}(0.09,0.471,0.157)   …  RGB{N0f8}(0.118,0.486,0.196)
#  RGB{N0f8}(0.09,0.475,0.169)      RGB{N0f8}(0.118,0.486,0.196)
#  RGB{N0f8}(0.09,0.475,0.169)      RGB{N0f8}(0.11,0.478,0.184)
#  RGB{N0f8}(0.094,0.475,0.169)     RGB{N0f8}(0.122,0.482,0.18)
#  RGB{N0f8}(0.098,0.478,0.173)     RGB{N0f8}(0.114,0.471,0.173)
#  RGB{N0f8}(0.094,0.475,0.169)  …  RGB{N0f8}(0.118,0.475,0.176)
#  RGB{N0f8}(0.094,0.475,0.169)     RGB{N0f8}(0.114,0.471,0.173)
#  RGB{N0f8}(0.098,0.459,0.157)     RGB{N0f8}(0.129,0.459,0.18)
#  RGB{N0f8}(0.102,0.463,0.165)     RGB{N0f8}(0.137,0.467,0.184)
#  RGB{N0f8}(0.102,0.463,0.165)     RGB{N0f8}(0.137,0.467,0.184)

# %%
plot_example_image(root_folder,"paper")
# Out:
# Type: Matrix{RGB{N0f8}}
# Shape: (200, 300)
# Colour channels: 3
# Size: 180.0 KB
# Max: 0.84313726
# Min: 0.0
# Image name: AjwddXm0ttm7Ts5J.png
# Class: paper
# 200×300 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.125,0.486,0.141)  …  RGB{N0f8}(0.141,0.478,0.133)
#  RGB{N0f8}(0.114,0.478,0.141)     RGB{N0f8}(0.133,0.482,0.133)
#  RGB{N0f8}(0.106,0.475,0.137)     RGB{N0f8}(0.137,0.486,0.137)
#  RGB{N0f8}(0.106,0.475,0.137)     RGB{N0f8}(0.137,0.486,0.137)
#  RGB{N0f8}(0.118,0.482,0.145)     RGB{N0f8}(0.149,0.498,0.149)
#  RGB{N0f8}(0.106,0.482,0.133)  …  RGB{N0f8}(0.129,0.498,0.145)
#  RGB{N0f8}(0.11,0.486,0.137)      RGB{N0f8}(0.129,0.498,0.145)
#  RGB{N0f8}(0.122,0.486,0.141)     RGB{N0f8}(0.133,0.49,0.137)
#  RGB{N0f8}(0.114,0.478,0.133)     RGB{N0f8}(0.133,0.49,0.137)
#  RGB{N0f8}(0.11,0.494,0.149)      RGB{N0f8}(0.129,0.506,0.149)
#  RGB{N0f8}(0.106,0.49,0.145)   …  RGB{N0f8}(0.125,0.502,0.145)
#  RGB{N0f8}(0.106,0.49,0.145)      RGB{N0f8}(0.129,0.498,0.145)
#  RGB{N0f8}(0.11,0.494,0.149)      RGB{N0f8}(0.129,0.498,0.145)
#  ⋮                             ⋱
#  RGB{N0f8}(0.102,0.494,0.157)     RGB{N0f8}(0.118,0.494,0.145)
#  RGB{N0f8}(0.094,0.498,0.157)     RGB{N0f8}(0.141,0.506,0.161)
#  RGB{N0f8}(0.09,0.494,0.153)   …  RGB{N0f8}(0.133,0.502,0.157)
#  RGB{N0f8}(0.094,0.498,0.157)     RGB{N0f8}(0.129,0.498,0.153)
#  RGB{N0f8}(0.09,0.494,0.153)      RGB{N0f8}(0.125,0.494,0.145)
#  RGB{N0f8}(0.102,0.494,0.157)     RGB{N0f8}(0.122,0.486,0.149)
#  RGB{N0f8}(0.102,0.494,0.157)     RGB{N0f8}(0.125,0.49,0.153)
#  RGB{N0f8}(0.098,0.49,0.153)   …  RGB{N0f8}(0.125,0.49,0.153)
#  RGB{N0f8}(0.094,0.486,0.149)     RGB{N0f8}(0.125,0.49,0.153)
#  RGB{N0f8}(0.102,0.475,0.145)     RGB{N0f8}(0.145,0.478,0.161)
#  RGB{N0f8}(0.106,0.478,0.149)     RGB{N0f8}(0.149,0.486,0.169)
#  RGB{N0f8}(0.11,0.482,0.161)      RGB{N0f8}(0.145,0.475,0.149)

# %%
plot_example_image(root_folder,"scissors")
# Out:
# Type: Matrix{RGB{N0f8}}
# Shape: (200, 300)
# Colour channels: 3
# Size: 180.0 KB
# Max: 0.88235295
# Min: 0.0
# Image name: asi6ZQCskd51eHm1.png
# Class: scissors
# 200×300 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.165,0.431,0.047)  …  RGB{N0f8}(0.267,0.275,0.212)
#  RGB{N0f8}(0.153,0.427,0.043)     RGB{N0f8}(0.133,0.341,0.102)
#  RGB{N0f8}(0.157,0.435,0.047)     RGB{N0f8}(0.129,0.337,0.098)
#  RGB{N0f8}(0.161,0.439,0.051)     RGB{N0f8}(0.122,0.318,0.094)
#  RGB{N0f8}(0.157,0.435,0.047)     RGB{N0f8}(0.11,0.306,0.078)
#  RGB{N0f8}(0.157,0.443,0.043)  …  RGB{N0f8}(0.106,0.192,0.11)
#  RGB{N0f8}(0.161,0.447,0.047)     RGB{N0f8}(0.024,0.11,0.027)
#  RGB{N0f8}(0.161,0.447,0.055)     RGB{N0f8}(0.02,0.071,0.035)
#  RGB{N0f8}(0.169,0.455,0.067)     RGB{N0f8}(0.016,0.067,0.031)
#  RGB{N0f8}(0.149,0.451,0.055)     RGB{N0f8}(0.02,0.055,0.043)
#  RGB{N0f8}(0.153,0.455,0.059)  …  RGB{N0f8}(0.02,0.055,0.043)
#  RGB{N0f8}(0.149,0.451,0.055)     RGB{N0f8}(0.016,0.051,0.039)
#  RGB{N0f8}(0.153,0.455,0.059)     RGB{N0f8}(0.016,0.051,0.039)
#  ⋮                             ⋱
#  RGB{N0f8}(0.141,0.463,0.051)     RGB{N0f8}(0.18,0.498,0.071)
#  RGB{N0f8}(0.145,0.467,0.067)     RGB{N0f8}(0.173,0.502,0.063)
#  RGB{N0f8}(0.145,0.467,0.067)  …  RGB{N0f8}(0.176,0.506,0.067)
#  RGB{N0f8}(0.141,0.463,0.059)     RGB{N0f8}(0.165,0.49,0.051)
#  RGB{N0f8}(0.141,0.463,0.059)     RGB{N0f8}(0.169,0.498,0.055)
#  RGB{N0f8}(0.141,0.463,0.051)     RGB{N0f8}(0.173,0.494,0.055)
#  RGB{N0f8}(0.149,0.475,0.063)     RGB{N0f8}(0.169,0.49,0.051)
#  RGB{N0f8}(0.149,0.475,0.063)  …  RGB{N0f8}(0.173,0.494,0.055)
#  RGB{N0f8}(0.145,0.471,0.059)     RGB{N0f8}(0.169,0.49,0.051)
#  RGB{N0f8}(0.161,0.467,0.071)     RGB{N0f8}(0.176,0.475,0.063)
#  RGB{N0f8}(0.165,0.471,0.075)     RGB{N0f8}(0.173,0.471,0.059)
#  RGB{N0f8}(0.165,0.471,0.075)     RGB{N0f8}(0.173,0.471,0.051)

# %% [markdown]
# # Load Images and Labels

# %%
using Random, Images
function get_images_and_labels(root_dir::String, image_size::Tuple{Int,Int}, shuffle_data::Bool, val_split::Float64, seed::Int=42)

    # initialise storage arrays
    label_categ = String[]
    image_paths = String[]
    labels = String[]

    # get image paths and labels
    for (index, (root, dirs, files)) in enumerate(walkdir(root_dir))
        (root == root_dir) && (label_categ = dirs)
        if index > 1
            new_images = map(x -> (root_dir * label_categ[index-1] * '/' * x), files)
            new_labels = repeat([label_categ[index-1]], length(files))
            image_paths = vcat(image_paths, new_images)
            labels = vcat(labels, new_labels)
        end
    end

    # load and scale images
    imgs = Images.load.(image_paths)
    # note: image_size is expected in the format (height, width)
    imgs = map(image -> Images.imresize(image, image_size), imgs)
    all_data = hcat(imgs, labels)

    # shuffle data
    Random.Random.seed!(seed)
    shuffle_data && (all_data = all_data[Random.shuffle(begin:end),:])

    # train / val split
    split_index = trunc(Int, (size(all_data)[1] * val_split))
    train = all_data[split_index+1:end,:]
    val = all_data[begin:split_index,:]

    return train[:,begin], train[:,end], val[:,begin], val[:,end], label_categ
end
# Out:
# get_images_and_labels (generic function with 2 methods)

# %%
IMAGE_HEIGHT = 160
IMAGE_WIDTH = 160
IMAGE_SIZE = (IMAGE_HEIGHT,IMAGE_WIDTH)
BATCH_SIZE = 32

X_train, y_train, X_val, y_val, categories = get_images_and_labels("$(root_folder)/", IMAGE_SIZE, true, 0.2, seed);

# %% [markdown]
# The dimensions of each array of data (i.e. the amount of sample in each array)

# %%
size(X_train), size(y_train), size(X_val), size(y_val)
# Out:
# ((480,), (480,), (120,), (120,))

# %% [markdown]
# A sample output image:

# %%
sample_number = 12 # must be less than the length of X_train, which in this case is 480 
println("Image dimensions: $(size(X_train[sample_number]))")
println("Label: $(y_train[sample_number])")
println()
ImageCore.colorview(RGB, X_train[sample_number])
# Out:
# Image dimensions: (160, 160)
# Label: scissors
# 160×160 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.196,0.576,0.255)  …  RGB{N0f8}(0.451,0.506,0.239)
#  RGB{N0f8}(0.184,0.576,0.247)     RGB{N0f8}(0.235,0.608,0.263)
#  RGB{N0f8}(0.188,0.58,0.251)      RGB{N0f8}(0.231,0.612,0.263)
#  RGB{N0f8}(0.184,0.576,0.247)     RGB{N0f8}(0.235,0.62,0.271)
#  RGB{N0f8}(0.196,0.576,0.243)     RGB{N0f8}(0.235,0.624,0.278)
#  RGB{N0f8}(0.196,0.576,0.243)  …  RGB{N0f8}(0.235,0.62,0.275)
#  RGB{N0f8}(0.192,0.58,0.247)      RGB{N0f8}(0.235,0.62,0.275)
#  RGB{N0f8}(0.192,0.592,0.255)     RGB{N0f8}(0.224,0.631,0.278)
#  RGB{N0f8}(0.192,0.592,0.255)     RGB{N0f8}(0.216,0.627,0.278)
#  RGB{N0f8}(0.18,0.584,0.243)      RGB{N0f8}(0.216,0.627,0.278)
#  RGB{N0f8}(0.176,0.584,0.239)  …  RGB{N0f8}(0.22,0.631,0.275)
#  RGB{N0f8}(0.173,0.584,0.239)     RGB{N0f8}(0.22,0.627,0.275)
#  RGB{N0f8}(0.176,0.588,0.243)     RGB{N0f8}(0.224,0.631,0.278)
#  ⋮                             ⋱
#  RGB{N0f8}(0.173,0.592,0.235)     RGB{N0f8}(0.165,0.529,0.2)
#  RGB{N0f8}(0.173,0.592,0.235)     RGB{N0f8}(0.169,0.529,0.2)
#  RGB{N0f8}(0.173,0.596,0.239)  …  RGB{N0f8}(0.169,0.533,0.204)
#  RGB{N0f8}(0.18,0.6,0.243)        RGB{N0f8}(0.157,0.545,0.2)
#  RGB{N0f8}(0.173,0.592,0.235)     RGB{N0f8}(0.153,0.537,0.196)
#  RGB{N0f8}(0.173,0.596,0.231)     RGB{N0f8}(0.153,0.537,0.196)
#  RGB{N0f8}(0.176,0.6,0.235)       RGB{N0f8}(0.153,0.541,0.2)
#  RGB{N0f8}(0.173,0.596,0.231)  …  RGB{N0f8}(0.149,0.541,0.2)
#  RGB{N0f8}(0.165,0.588,0.224)     RGB{N0f8}(0.145,0.537,0.192)
#  RGB{N0f8}(0.184,0.596,0.231)     RGB{N0f8}(0.157,0.533,0.2)
#  RGB{N0f8}(0.212,0.6,0.239)       RGB{N0f8}(0.169,0.529,0.208)
#  RGB{N0f8}(0.212,0.6,0.243)       RGB{N0f8}(0.165,0.529,0.204)

# %% [markdown]
# All the categories available:

# %%
categories
# Out:
# 3-element Vector{String}:
#  "paper"
#  "rock"
#  "scissors"

# %% [markdown]
# # Image datatype
#
# In julia when images are loaded in they are of type N0f8 (Normalized, with 0 integer bits and 8 fractional bits). With all values sitting between 0 and 1.

# %%
typeof(X_train[1]), typeof(y_train[1])
# Out:
# (Matrix{RGB{N0f8}}, String)

# %% [markdown]
# # Construct augmentation pipelines and augment images
#
# The first pipeline is for the training data:
#
# * Perform random augmentations to images (rotate, horizontal flip and zoom)
# * Resize the images to 160x160
# * Split the image into three separate color channels (red, green and blue)
# * Change the channel order to (width, height, color channels)
# * Change datatype from N0f8 to Float32
#
# You may note that the "get_images_and_labels" function already scaled the images to 160x160. So why repeat the process?
#
# Some of the augmentation functions act on the image in a way that causes the overall size of the image to change. In this case is the rotate function. So it is necessary to scale the images back down to 160x160 afterwards.

# %%
using Augmentor
train_pipe = Augmentor.Rotate(collect(StepRange(-70, 5, 70))) |>
             Augmentor.FlipX() * Augmentor.NoOp() |>
             Augmentor.Resize(IMAGE_SIZE...) |>
             Augmentor.Zoom(collect(StepRange(80, 5, 120))/100) |>
             Augmentor.SplitChannels() |>
             Augmentor.PermuteDims((3, 2, 1))|>
             Augmentor.ConvertEltype(Float32)
# Out:
# 7-step Augmentor.ImmutablePipeline:
#  1.) Rotate by θ ∈ [-70, -65, -60, -55, -50, -45, -40, -35, -30, -25  …  25, 30, 35, 40, 45, 50, 55, 60, 65, 70] degree
#  2.) Either: (50%) Flip the X axis. (50%) No operation.
#  3.) Resize to 160×160
#  4.) Zoom by I ∈ {0.8×0.8, 0.85×0.85, 0.9×0.9, 0.95×0.95, 1.0×1.0, 1.05×1.05, 1.1×1.1, 1.15×1.15, 1.2×1.2}
#  5.) Split colorant into its color channels
#  6.) Permute dimension order to (3, 2, 1)
#  7.) Convert eltype to Float32

# %% [markdown]
# The second pipeline is for the validation data (and hold out test data):
#
# * Split the image into three separate color channels (red, green and blue)
# * Change the channel order to (width, height, color channels)
# * Change datatype from N0f8 to Float32
#
# As you can see, when no augmentations are performed the re-scaling of the images is not necessary.

# %%
using Augmentor
val_pipe = Augmentor.SplitChannels() |>
           Augmentor.PermuteDims((3, 2, 1)) |>
           Augmentor.ConvertEltype(Float32)
# Out:
# 3-step Augmentor.ImmutablePipeline:
#  1.) Split colorant into its color channels
#  2.) Permute dimension order to (3, 2, 1)
#  3.) Convert eltype to Float32

# %% [markdown]
# ## Augmentation function

# %%
using MLUtils, Augmentor, OneHotArrays
function augment_images_one_hot_labels(images, labels, image_height::Int, image_width::Int, augmentor, categories)
    
    # input to the model requires WHCN format (width, height, channels, batchs/samples)
    aug_images = Array{Float32}(undef, (image_width, image_height, 3, MLUtils.numobs(images)))
    
    # augment the images
    for (index, image) in enumerate(images)
        aug_images[:,:,:,index] = Augmentor.augment(image, augmentor)
    end
    
    # one hot encode the labels
    one_hot_labels = OneHotArrays.onehotbatch(labels, categories)
    
    return aug_images, one_hot_labels
end
# Out:
# augment_images_one_hot_labels (generic function with 1 method)

# %% [markdown]
# ## Run the augmentation on the images

# %%
X_train_aug, y_train_one_hot = augment_images_one_hot_labels(X_train, y_train, IMAGE_SIZE..., train_pipe, categories);

# %%
X_val_aug, y_val_one_hot = augment_images_one_hot_labels(X_val, y_val, IMAGE_SIZE..., val_pipe, categories);

# %% [markdown]
# ## Check the outputs make sense
#
# We should have:
#
# (width, height, colour channels, samples)
#
# (categories, samples)
#
# Note: categories will be 3 rather than 1 as the labels are now one-hot encoded

# %%
size(X_train_aug), size(y_train_one_hot)
# Out:
# ((160, 160, 3, 480), (3, 480))

# %%
size(X_val_aug), size(y_val_one_hot)
# Out:
# ((160, 160, 3, 120), (3, 120))

# %% [markdown]
# ## Some random images to view the augmentation
#
# Note: colorview uses (color channels, heigth, width)

# %%
using Random, ImageCore  
function plot_random_images(input_images, number)
    images = Array{Any}(undef,number)
    for i in 1:number
        rand_index = Random.rand(1:size(input_images)[4])
        image = permutedims(input_images[:,:,:,rand_index],(3,2,1))
        images[i] = image
    end
    images = map(x -> ImageCore.colorview(RGB, x), images)
    return images
end
# Out:
# plot_random_images (generic function with 1 method)

# %% [markdown]
# ### Train data

# %%
plot_random_images(X_train_aug, 6)
# Out:
# 6-element Vector{Base.ReinterpretArray{RGB{Float32}, 2, Float32, Array{Float32, 3}, true}}:
#  [RGB{Float32}(0.15294118f0,0.5411765f0,0.1882353f0) RGB{Float32}(0.15686275f0,0.54509807f0,0.19215687f0) … RGB{Float32}(0.13725491f0,0.52156866f0,0.19607843f0) RGB{Float32}(0.13725491f0,0.52156866f0,0.19607843f0); RGB{Float32}(0.15294118f0,0.5372549f0,0.19215687f0) RGB{Float32}(0.15294118f0,0.5411765f0,0.1882353f0) … RGB{Float32}(0.13725491f0,0.52156866f0,0.19607843f0) RGB{Float32}(0.13725491f0,0.52156866f0,0.2f0); … ; RGB{Float32}(0.09019608f0,0.27058825f0,0.05882353f0) RGB{Float32}(0.09411765f0,0.2784314f0,0.0627451f0) … RGB{Float32}(0.13725491f0,0.5294118f0,0.19607843f0) RGB{Float32}(0.13725491f0,0.5294118f0,0.19607843f0); RGB{Float32}(0.101960786f0,0.2901961f0,0.07058824f0) RGB{Float32}(0.105882354f0,0.29803923f0,0.07450981f0) … RGB{Float32}(0.13725491f0,0.5294118f0,0.1882353f0) RGB{Float32}(0.13725491f0,0.5294118f0,0.19607843f0)]
#  [RGB{Float32}(0.4f0,0.4509804f0,0.24313726f0) RGB{Float32}(0.4f0,0.4509804f0,0.24313726f0) … RGB{Float32}(0.16078432f0,0.45490196f0,0.14509805f0) RGB{Float32}(0.16078432f0,0.45490196f0,0.14509805f0); RGB{Float32}(0.4f0,0.4509804f0,0.24313726f0) RGB{Float32}(0.4f0,0.4509804f0,0.24313726f0) … RGB{Float32}(0.16078432f0,0.45490196f0,0.14509805f0) RGB{Float32}(0.16078432f0,0.45490196f0,0.14509805f0); … ; RGB{Float32}(0.15686275f0,0.43137255f0,0.09019608f0) RGB{Float32}(0.15686275f0,0.43137255f0,0.09019608f0) … RGB{Float32}(0.1254902f0,0.44313726f0,0.11764706f0) RGB{Float32}(0.1254902f0,0.44313726f0,0.11764706f0); RGB{Float32}(0.15686275f0,0.43137255f0,0.09019608f0) RGB{Float32}(0.15686275f0,0.43137255f0,0.09019608f0) … RGB{Float32}(0.1254902f0,0.44313726f0,0.11764706f0) RGB{Float32}(0.1254902f0,0.44313726f0,0.11764706f0)]
#  [RGB{Float32}(0.2784314f0,0.64705884f0,0.3137255f0) RGB{Float32}(0.2784314f0,0.64705884f0,0.30588236f0) … RGB{Float32}(0.15294118f0,0.5647059f0,0.21568628f0) RGB{Float32}(0.16078432f0,0.5647059f0,0.21568628f0); RGB{Float32}(0.2509804f0,0.61960787f0,0.28627452f0) RGB{Float32}(0.2901961f0,0.65882355f0,0.32156864f0) … RGB{Float32}(0.16078432f0,0.5647059f0,0.21568628f0) RGB{Float32}(0.15686275f0,0.5568628f0,0.20784314f0); … ; RGB{Float32}(0.1882353f0,0.4745098f0,0.18039216f0) RGB{Float32}(0.18039216f0,0.45882353f0,0.16862746f0) … RGB{Float32}(0.5803922f0,0.4117647f0,0.25490198f0) RGB{Float32}(0.5686275f0,0.4f0,0.24313726f0); RGB{Float32}(0.17254902f0,0.4509804f0,0.16078432f0) RGB{Float32}(0.16470589f0,0.4509804f0,0.15686275f0) … RGB{Float32}(0.5921569f0,0.41960785f0,0.25882354f0) RGB{Float32}(0.5764706f0,0.40784314f0,0.2509804f0)]
#  [RGB{Float32}(0.12156863f0,0.49019608f0,0.15294118f0) RGB{Float32}(0.12156863f0,0.49019608f0,0.15294118f0) … RGB{Float32}(0.16078432f0,0.5137255f0,0.18039216f0) RGB{Float32}(0.15686275f0,0.50980395f0,0.1764706f0); RGB{Float32}(0.1254902f0,0.49411765f0,0.15686275f0) RGB{Float32}(0.1254902f0,0.49411765f0,0.15686275f0) … RGB{Float32}(0.16078432f0,0.5137255f0,0.18039216f0) RGB{Float32}(0.15294118f0,0.50980395f0,0.1764706f0); … ; RGB{Float32}(0.14509805f0,0.42352942f0,0.1254902f0) RGB{Float32}(0.14901961f0,0.43529412f0,0.1254902f0) … RGB{Float32}(0.11764706f0,0.5137255f0,0.16078432f0) RGB{Float32}(0.11764706f0,0.50980395f0,0.16078432f0); RGB{Float32}(0.14509805f0,0.42745098f0,0.1254902f0) RGB{Float32}(0.14901961f0,0.43529412f0,0.12941177f0) … RGB{Float32}(0.12156863f0,0.5137255f0,0.16470589f0) RGB{Float32}(0.11764706f0,0.5137255f0,0.16078432f0)]
#  [RGB{Float32}(0.12941177f0,0.48235294f0,0.16078432f0) RGB{Float32}(0.12941177f0,0.48235294f0,0.16078432f0) … RGB{Float32}(0.15686275f0,0.47843137f0,0.16470589f0) RGB{Float32}(0.15686275f0,0.48235294f0,0.16862746f0); RGB{Float32}(0.12941177f0,0.47843137f0,0.15686275f0) RGB{Float32}(0.12941177f0,0.47843137f0,0.15686275f0) … RGB{Float32}(0.15686275f0,0.47843137f0,0.16470589f0) RGB{Float32}(0.15686275f0,0.48235294f0,0.16862746f0); … ; RGB{Float32}(0.1254902f0,0.48235294f0,0.14901961f0) RGB{Float32}(0.13333334f0,0.49803922f0,0.16470589f0) … RGB{Float32}(0.12156863f0,0.49411765f0,0.17254902f0) RGB{Float32}(0.12156863f0,0.49803922f0,0.17254902f0); RGB{Float32}(0.1254902f0,0.48235294f0,0.14901961f0) RGB{Float32}(0.13333334f0,0.49803922f0,0.16470589f0) … RGB{Float32}(0.11764706f0,0.49019608f0,0.17254902f0) RGB{Float32}(0.11764706f0,0.49019608f0,0.17254902f0)]
#  [RGB{Float32}(0.18039216f0,0.5294118f0,0.09803922f0) RGB{Float32}(0.1764706f0,0.5294118f0,0.09411765f0) … RGB{Float32}(0.6862745f0,0.46666667f0,0.21176471f0) RGB{Float32}(0.6862745f0,0.46666667f0,0.21176471f0); RGB{Float32}(0.18431373f0,0.5254902f0,0.09803922f0) RGB{Float32}(0.1764706f0,0.53333336f0,0.09803922f0) … RGB{Float32}(0.6901961f0,0.47058824f0,0.21960784f0) RGB{Float32}(0.6901961f0,0.47058824f0,0.22352941f0); … ; RGB{Float32}(0.15686275f0,0.49019608f0,0.07450981f0) RGB{Float32}(0.15686275f0,0.4862745f0,0.07058824f0) … RGB{Float32}(0.16470589f0,0.49019608f0,0.07058824f0) RGB{Float32}(0.15294118f0,0.47843137f0,0.0627451f0); RGB{Float32}(0.15686275f0,0.4862745f0,0.07450981f0) RGB{Float32}(0.15686275f0,0.4862745f0,0.078431375f0) … RGB{Float32}(0.16470589f0,0.49019608f0,0.07058824f0) RGB{Float32}(0.15686275f0,0.48235294f0,0.06666667f0)]

# %%
using ImageCore
sample_number = 50
println("Augmented train data type: $(typeof(X_train_aug[:,:,:,sample_number]))")
println("Output label:              $(y_train_one_hot[:,sample_number])")
println("From categories:           $(categories)")
println()
ImageCore.colorview(RGB, permutedims(X_train_aug[:,:,:,sample_number],(3,2,1)))
# Out:
# Augmented train data type: Array{Float32, 3}
# Output label:              Bool[0, 0, 1]
# From categories:           ["paper", "rock", "scissors"]
# 160×160 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.14902,0.513726,0.184314)   …  RGB{Float32}(0.109804,0.509804,0.168627)
#  RGB{Float32}(0.141176,0.505882,0.172549)     RGB{Float32}(0.109804,0.509804,0.168627)
#  RGB{Float32}(0.14902,0.517647,0.188235)      RGB{Float32}(0.109804,0.509804,0.172549)
#  RGB{Float32}(0.152941,0.517647,0.188235)     RGB{Float32}(0.109804,0.509804,0.172549)
#  RGB{Float32}(0.156863,0.52549,0.196078)      RGB{Float32}(0.109804,0.513726,0.172549)
#  RGB{Float32}(0.14902,0.52549,0.188235)    …  RGB{Float32}(0.109804,0.513726,0.172549)
#  RGB{Float32}(0.145098,0.521569,0.180392)     RGB{Float32}(0.109804,0.513726,0.172549)
#  RGB{Float32}(0.152941,0.529412,0.188235)     RGB{Float32}(0.109804,0.509804,0.172549)
#  RGB{Float32}(0.14902,0.529412,0.188235)      RGB{Float32}(0.109804,0.509804,0.172549)
#  RGB{Float32}(0.145098,0.529412,0.188235)     RGB{Float32}(0.105882,0.505882,0.168627)
#  RGB{Float32}(0.14902,0.533333,0.196078)   …  RGB{Float32}(0.105882,0.505882,0.168627)
#  RGB{Float32}(0.145098,0.533333,0.2)          RGB{Float32}(0.105882,0.509804,0.168627)
#  RGB{Float32}(0.145098,0.533333,0.196078)     RGB{Float32}(0.105882,0.509804,0.168627)
#  ⋮                                         ⋱
#  RGB{Float32}(0.121569,0.509804,0.156863)     RGB{Float32}(0.14902,0.545098,0.192157)
#  RGB{Float32}(0.121569,0.509804,0.156863)     RGB{Float32}(0.137255,0.533333,0.184314)
#  RGB{Float32}(0.12549,0.513726,0.160784)   …  RGB{Float32}(0.141176,0.537255,0.192157)
#  RGB{Float32}(0.129412,0.513726,0.160784)     RGB{Float32}(0.14902,0.541176,0.196078)
#  RGB{Float32}(0.129412,0.513726,0.160784)     RGB{Float32}(0.137255,0.533333,0.184314)
#  RGB{Float32}(0.129412,0.513726,0.160784)     RGB{Float32}(0.14902,0.541176,0.196078)
#  RGB{Float32}(0.133333,0.513726,0.160784)     RGB{Float32}(0.14902,0.533333,0.188235)
#  RGB{Float32}(0.137255,0.513726,0.164706)  …  RGB{Float32}(0.145098,0.529412,0.184314)
#  RGB{Float32}(0.137255,0.513726,0.164706)     RGB{Float32}(0.145098,0.529412,0.184314)
#  RGB{Float32}(0.133333,0.513726,0.164706)     RGB{Float32}(0.133333,0.517647,0.164706)
#  RGB{Float32}(0.133333,0.513726,0.164706)     RGB{Float32}(0.141176,0.52549,0.172549)
#  RGB{Float32}(0.129412,0.513726,0.160784)     RGB{Float32}(0.141176,0.52549,0.180392)

# %% [markdown]
# ### Val data

# %%
plot_random_images(X_val_aug, 6)
# Out:
# 6-element Vector{Base.ReinterpretArray{RGB{Float32}, 2, Float32, Array{Float32, 3}, true}}:
#  [RGB{Float32}(0.09019608f0,0.47058824f0,0.1254902f0) RGB{Float32}(0.09019608f0,0.4745098f0,0.1254902f0) … RGB{Float32}(0.043137256f0,0.33333334f0,0.019607844f0) RGB{Float32}(0.03529412f0,0.31764707f0,0.019607844f0); RGB{Float32}(0.08627451f0,0.46666667f0,0.12156863f0) RGB{Float32}(0.09411765f0,0.48235294f0,0.12941177f0) … RGB{Float32}(0.039215688f0,0.32941177f0,0.023529412f0) RGB{Float32}(0.03137255f0,0.31764707f0,0.019607844f0); … ; RGB{Float32}(0.09411765f0,0.40392157f0,0.07058824f0) RGB{Float32}(0.101960786f0,0.42352942f0,0.08235294f0) … RGB{Float32}(0.05490196f0,0.34509805f0,0.03529412f0) RGB{Float32}(0.050980393f0,0.33333334f0,0.039215688f0); RGB{Float32}(0.09411765f0,0.40392157f0,0.07058824f0) RGB{Float32}(0.09803922f0,0.41568628f0,0.07450981f0) … RGB{Float32}(0.050980393f0,0.34117648f0,0.03137255f0) RGB{Float32}(0.047058824f0,0.32941177f0,0.02745098f0)]
#  [RGB{Float32}(0.1254902f0,0.45882353f0,0.15294118f0) RGB{Float32}(0.12156863f0,0.45490196f0,0.14901961f0) … RGB{Float32}(0.09019608f0,0.4117647f0,0.11372549f0) RGB{Float32}(0.09411765f0,0.40784314f0,0.105882354f0); RGB{Float32}(0.11372549f0,0.46666667f0,0.15294118f0) RGB{Float32}(0.10980392f0,0.4627451f0,0.14901961f0) … RGB{Float32}(0.09411765f0,0.40784314f0,0.105882354f0) RGB{Float32}(0.09411765f0,0.40784314f0,0.105882354f0); … ; RGB{Float32}(0.105882354f0,0.4862745f0,0.15294118f0) RGB{Float32}(0.10980392f0,0.4862745f0,0.15686275f0) … RGB{Float32}(0.14117648f0,0.49019608f0,0.16862746f0) RGB{Float32}(0.14509805f0,0.49019608f0,0.17254902f0); RGB{Float32}(0.10980392f0,0.4862745f0,0.15686275f0) RGB{Float32}(0.10980392f0,0.4862745f0,0.15294118f0) … RGB{Float32}(0.13725491f0,0.49019608f0,0.16862746f0) RGB{Float32}(0.14117648f0,0.49019608f0,0.16470589f0)]
#  [RGB{Float32}(0.14117648f0,0.49019608f0,0.16862746f0) RGB{Float32}(0.13333334f0,0.48235294f0,0.15686275f0) … RGB{Float32}(0.14509805f0,0.4862745f0,0.14901961f0) RGB{Float32}(0.14509805f0,0.48235294f0,0.14509805f0); RGB{Float32}(0.11764706f0,0.49411765f0,0.16470589f0) RGB{Float32}(0.12156863f0,0.49803922f0,0.16470589f0) … RGB{Float32}(0.13333334f0,0.49019608f0,0.14117648f0) RGB{Float32}(0.13725491f0,0.49019608f0,0.14509805f0); … ; RGB{Float32}(0.12156863f0,0.48235294f0,0.15686275f0) RGB{Float32}(0.11764706f0,0.4862745f0,0.15294118f0) … RGB{Float32}(0.12156863f0,0.4862745f0,0.14901961f0) RGB{Float32}(0.13333334f0,0.4862745f0,0.16078432f0); RGB{Float32}(0.11764706f0,0.48235294f0,0.15686275f0) RGB{Float32}(0.11764706f0,0.48235294f0,0.15686275f0) … RGB{Float32}(0.1254902f0,0.49019608f0,0.15294118f0) RGB{Float32}(0.13333334f0,0.4862745f0,0.15686275f0)]
#  [RGB{Float32}(0.1254902f0,0.4509804f0,0.14901961f0) RGB{Float32}(0.11764706f0,0.44313726f0,0.13725491f0) … RGB{Float32}(0.14117648f0,0.45882353f0,0.15294118f0) RGB{Float32}(0.13333334f0,0.4509804f0,0.14901961f0); RGB{Float32}(0.11764706f0,0.4509804f0,0.14509805f0) RGB{Float32}(0.11764706f0,0.45490196f0,0.14509805f0) … RGB{Float32}(0.12941177f0,0.4627451f0,0.14901961f0) RGB{Float32}(0.1254902f0,0.45490196f0,0.13725491f0); … ; RGB{Float32}(0.105882354f0,0.47843137f0,0.16078432f0) RGB{Float32}(0.105882354f0,0.4745098f0,0.16078432f0) … RGB{Float32}(0.10980392f0,0.32156864f0,0.0627451f0) RGB{Float32}(0.10980392f0,0.32156864f0,0.06666667f0); RGB{Float32}(0.105882354f0,0.4745098f0,0.16078432f0) RGB{Float32}(0.105882354f0,0.47843137f0,0.15686275f0) … RGB{Float32}(0.11764706f0,0.3254902f0,0.06666667f0) RGB{Float32}(0.11764706f0,0.3254902f0,0.07058824f0)]
#  [RGB{Float32}(0.13333334f0,0.4627451f0,0.14509805f0) RGB{Float32}(0.1254902f0,0.45490196f0,0.14117648f0) … RGB{Float32}(0.1254902f0,0.4509804f0,0.15686275f0) RGB{Float32}(0.12156863f0,0.44705883f0,0.14509805f0); RGB{Float32}(0.11764706f0,0.4627451f0,0.14117648f0) RGB{Float32}(0.11372549f0,0.45882353f0,0.13725491f0) … RGB{Float32}(0.1254902f0,0.44705883f0,0.14509805f0) RGB{Float32}(0.12156863f0,0.4509804f0,0.15294118f0); … ; RGB{Float32}(0.11372549f0,0.4627451f0,0.12941177f0) RGB{Float32}(0.10980392f0,0.4627451f0,0.12941177f0) … RGB{Float32}(0.13725491f0,0.45490196f0,0.14117648f0) RGB{Float32}(0.14509805f0,0.45490196f0,0.14509805f0); RGB{Float32}(0.10980392f0,0.45882353f0,0.1254902f0) RGB{Float32}(0.11372549f0,0.46666667f0,0.13333334f0) … RGB{Float32}(0.14117648f0,0.45882353f0,0.13725491f0) RGB{Float32}(0.14117648f0,0.45490196f0,0.14117648f0)]
#  [RGB{Float32}(0.07058824f0,0.36862746f0,0.08627451f0) RGB{Float32}(0.078431375f0,0.38431373f0,0.08235294f0) … RGB{Float32}(0.043137256f0,0.32156864f0,0.043137256f0) RGB{Float32}(0.03529412f0,0.30588236f0,0.03137255f0); RGB{Float32}(0.07450981f0,0.3764706f0,0.09019608f0) RGB{Float32}(0.08235294f0,0.39215687f0,0.09411765f0) … RGB{Float32}(0.043137256f0,0.3254902f0,0.043137256f0) RGB{Float32}(0.03529412f0,0.30980393f0,0.03529412f0); … ; RGB{Float32}(0.10980392f0,0.44705883f0,0.09411765f0) RGB{Float32}(0.10980392f0,0.4509804f0,0.09411765f0) … RGB{Float32}(0.0627451f0,0.3254902f0,0.003921569f0) RGB{Float32}(0.047058824f0,0.30980393f0,0.0f0); RGB{Float32}(0.10980392f0,0.44313726f0,0.09411765f0) RGB{Float32}(0.10980392f0,0.4509804f0,0.09411765f0) … RGB{Float32}(0.0627451f0,0.32941177f0,0.007843138f0) RGB{Float32}(0.05490196f0,0.3137255f0,0.0f0)]

# %%
using ImageCore
sample_number = 50
println("Augmented train data type: $(typeof(X_val_aug[:,:,:,sample_number]))")
println("Output label:              $(y_val_one_hot[:,sample_number])")
println("From categories:           $(categories)")
println()
ImageCore.colorview(RGB, permutedims(X_val_aug[:,:,:,sample_number],(3,2,1)))
# Out:
# Augmented train data type: Array{Float32, 3}
# Output label:              Bool[1, 0, 0]
# From categories:           ["paper", "rock", "scissors"]
# 160×160 reinterpret(reshape, RGB{Float32}, ::Array{Float32, 3}) with eltype RGB{Float32}:
#  RGB{Float32}(0.243137,0.54902,0.188235)   …  RGB{Float32}(0.278431,0.490196,0.152941)
#  RGB{Float32}(0.239216,0.556863,0.192157)     RGB{Float32}(0.235294,0.505882,0.145098)
#  RGB{Float32}(0.243137,0.560784,0.196078)     RGB{Float32}(0.231373,0.501961,0.141176)
#  RGB{Float32}(0.239216,0.556863,0.192157)     RGB{Float32}(0.215686,0.486275,0.129412)
#  RGB{Float32}(0.231373,0.576471,0.2)          RGB{Float32}(0.203922,0.482353,0.121569)
#  RGB{Float32}(0.235294,0.580392,0.203922)  …  RGB{Float32}(0.207843,0.482353,0.12549)
#  RGB{Float32}(0.231373,0.576471,0.2)          RGB{Float32}(0.207843,0.482353,0.12549)
#  RGB{Float32}(0.223529,0.572549,0.188235)     RGB{Float32}(0.2,0.478431,0.12549)
#  RGB{Float32}(0.219608,0.568627,0.184314)     RGB{Float32}(0.184314,0.462745,0.109804)
#  RGB{Float32}(0.223529,0.568627,0.188235)     RGB{Float32}(0.184314,0.462745,0.113725)
#  RGB{Float32}(0.215686,0.580392,0.196078)  …  RGB{Float32}(0.192157,0.466667,0.117647)
#  RGB{Float32}(0.215686,0.592157,0.207843)     RGB{Float32}(0.196078,0.466667,0.117647)
#  RGB{Float32}(0.219608,0.596078,0.211765)     RGB{Float32}(0.192157,0.466667,0.12549)
#  ⋮                                         ⋱
#  RGB{Float32}(0.219608,0.607843,0.2)          RGB{Float32}(0.286275,0.678431,0.243137)
#  RGB{Float32}(0.219608,0.603922,0.2)          RGB{Float32}(0.286275,0.678431,0.243137)
#  RGB{Float32}(0.211765,0.596078,0.192157)  …  RGB{Float32}(0.286275,0.678431,0.243137)
#  RGB{Float32}(0.207843,0.592157,0.180392)     RGB{Float32}(0.286275,0.678431,0.243137)
#  RGB{Float32}(0.203922,0.592157,0.176471)     RGB{Float32}(0.282353,0.67451,0.243137)
#  RGB{Float32}(0.211765,0.596078,0.180392)     RGB{Float32}(0.278431,0.67451,0.239216)
#  RGB{Float32}(0.211765,0.596078,0.184314)     RGB{Float32}(0.282353,0.67451,0.243137)
#  RGB{Float32}(0.207843,0.592157,0.184314)  …  RGB{Float32}(0.286275,0.678431,0.247059)
#  RGB{Float32}(0.203922,0.588235,0.180392)     RGB{Float32}(0.286275,0.678431,0.247059)
#  RGB{Float32}(0.207843,0.588235,0.180392)     RGB{Float32}(0.282353,0.662745,0.235294)
#  RGB{Float32}(0.211765,0.580392,0.172549)     RGB{Float32}(0.294118,0.65098,0.235294)
#  RGB{Float32}(0.219608,0.584314,0.172549)     RGB{Float32}(0.294118,0.65098,0.235294)

# %% [markdown]
# # Prepare and batch data ready for input into the model

# %%
using Flux
train_batches = Flux.DataLoader((X_train_aug, y_train_one_hot), batchsize=BATCH_SIZE, shuffle=false)
# Out:
# 15-element DataLoader(::Tuple{Array{Float32, 4}, OneHotMatrix{UInt32, Vector{UInt32}}}, batchsize=32)
#   with first element:
#   (160×160×3×32 Array{Float32, 4}, 3×32 OneHotMatrix(::Vector{UInt32}) with eltype Bool,)

# %%
using Flux
val_batches = Flux.DataLoader((X_val_aug, y_val_one_hot), batchsize=BATCH_SIZE, shuffle=false)
# Out:
# 4-element DataLoader(::Tuple{Array{Float32, 4}, OneHotMatrix{UInt32, Vector{UInt32}}}, batchsize=32)
#   with first element:
#   (160×160×3×32 Array{Float32, 4}, 3×32 OneHotMatrix(::Vector{UInt32}) with eltype Bool,)

# %% [markdown]
# # Define the model
#
# At the end of the "chain" you can see that it is assigned to the cpu. You do not need to include this. If omitted it will work exactly the same.
#
# However, to use a GPU you would need to change "cpu" to "gpu", and it would need to be included. I have included it just to aid in switching to GPU should you wish to do so.

# %%
using Flux
# set whether to use the cpu or gpu for calculations
calc_device = gpu

(width, height, channels, records) = size(X_train_aug)

model = Flux.Chain(Flux.Conv((3, 3), channels=>32, pad=(1,1), selu),
                   Flux.MaxPool((2, 2)),
                   Flux.Conv((3, 3), 32=>64,pad=(1,1), selu),
                   Flux.MaxPool((2, 2)),
                   Flux.Conv((3, 3), 64=>64,pad=(1,1), selu),
                   Flux.MaxPool((2, 2)),
                   Flux.GlobalMeanPool(),
                   Flux.flatten,
                   Flux.Dense(64,64, selu),
                   Flux.Dense(64,3)) |> calc_device
# Out:
#  Downloading artifact: CUDA_compat
#  Downloading artifact: CUDA
#  Downloading artifact: CUDNN
# Chain(
#   Conv((3, 3), 3 => 32, selu, pad=1),   # 896 parameters
#   MaxPool((2, 2)),
#   Conv((3, 3), 32 => 64, selu, pad=1),  # 18_496 parameters
#   MaxPool((2, 2)),
#   Conv((3, 3), 64 => 64, selu, pad=1),  # 36_928 parameters
#   MaxPool((2, 2)),
#   GlobalMeanPool(),
#   Flux.flatten,
#   Dense(64 => 64, selu),                # 4_160 parameters
#   Dense(64 => 3),                       # 195 parameters
# )                   # Total: 10 arrays, 60_675 parameters, 2.297 KiB.

# %% [markdown]
# # Define loss function and any other metrics
#
# You may note in the definition of the model that there is no softmax layer defined. This is due to the fact that it is not required.
#
# If (for a multi-class classification problem) you use 'logitcrossentropy' for the loss, then it is not necessary to use softmax as it already has the funcitonality built in. The equivalent would be using 'crossentropy' along with softmax in the model.
#
# However, it should be noted that it is recommended to use 'logitcrossentropy' as it is ['more numerically stable than using functions crossentropy and softmax separately.'](https://fluxml.ai/Flux.jl/stable/models/losses/#Flux.Losses.logitcrossentropy)

# %%
using Statistics, Flux
loss(X, y) = Flux.Losses.logitcrossentropy(model(X), y)
accuracy(X, y) = Statistics.mean(Flux.onecold(model(X)) .== Flux.onecold(y))
# Out:
# accuracy (generic function with 1 method)

# %% [markdown]
# # Define the optimiser

# %%
using Flux
opt = Flux.Optimise.ADAM(0.001)
# Out:
# Adam(0.001, (0.9, 0.999), 1.0e-8, IdDict{Any, Any}())

# %% [markdown]
# # Define the training loop
#
# There is a much simpler way of training using Julia using the train function, which is very similar to using "model.fit" in Tensorflow:
#
# ```Julia
# for epoch in 1:10
#     Flux.train!(loss, Flux.params(model), train_batches, opt)
# end
# ```
#
# However, using the above method can cause problems when dealing with large amounts of data (like images), as it requires loading all of the train data into memory.
#
# The following function therefore allows the batches to be loaded onto the gpu (or memory for a cpu run) batch by batch. It also prints the training loss and accuracy (an average over all batches), and the validation loss on the whole validation dataset.
#
# **Note:** If the validation set is quite large you could also calculate the validation loss/accuracy on a batch by batch basis to save memory.

# %%
using Flux
function train_model(dataloader, num_epochs::Int, model, optimiser, val_data, val_labels, device)

    num_batches = length(dataloader)
    
    for epoch in 1:num_epochs

        batch_loss = 0.0
        batch_acc = 0.0

        for (count, (batch_data, batch_labels)) in enumerate(dataloader)

            # assign each batch to the device
            x, y = device(batch_data), device(batch_labels)
            gradients = Flux.gradient(() -> loss(x, y), Flux.params(model))
            Flux.Optimise.update!(optimiser, Flux.params(model), gradients)

            # collect the loss and accuracy from each batch
            batch_loss += loss(x, y)
            batch_acc += accuracy(x, y)

            # output the loss and accuracy at the end of each epoch
            if num_batches == count
                println("Epoch: $(epoch)")
                # calculate the average loss/accuracy for each epoch from the collected batches
                print("Training Loss: $(round((batch_loss / num_batches), digits=2)) ")
                print("Training Acc: $(round((batch_acc / num_batches), digits=2)) ")
                # calculate the validation loss/accuracy on the whole validation set
                print("Validation Loss: $(round(loss(device(val_data), device(val_labels)), digits=2)) ")
                print("Validation Acc: $(round(accuracy(device(val_data), device(val_labels)), digits=2))")
                println()
            end
        end
    end
end
# Out:
# train_model (generic function with 1 method)

# %%
train_model(train_batches, 20, model, opt, X_val_aug, y_val_one_hot, calc_device)
# Out:
# Epoch: 1
# Training Loss: 1.15 Training Acc: 0.38 Validation Loss: 1.06 Validation Acc: 0.33
# Epoch: 2
# Training Loss: 1.05 Training Acc: 0.42 Validation Loss: 1.08 Validation Acc: 0.37
# Epoch: 3
# Training Loss: 1.03 Training Acc: 0.46 Validation Loss: 1.0 Validation Acc: 0.41
# Epoch: 4
# Training Loss: 1.03 Training Acc: 0.48 Validation Loss: 0.98 Validation Acc: 0.52
# Epoch: 5
# Training Loss: 1.01 Training Acc: 0.49 Validation Loss: 1.0 Validation Acc: 0.48
# Epoch: 6
# Training Loss: 1.0 Training Acc: 0.51 Validation Loss: 0.96 Validation Acc: 0.52
# Epoch: 7
# Training Loss: 1.0 Training Acc: 0.5 Validation Loss: 0.97 Validation Acc: 0.52
# Epoch: 8
# Training Loss: 0.98 Training Acc: 0.51 Validation Loss: 0.97 Validation Acc: 0.49
# Epoch: 9
# Training Loss: 0.98 Training Acc: 0.54 Validation Loss: 0.95 Validation Acc: 0.5
# Epoch: 10
# Training Loss: 0.97 Training Acc: 0.54 Validation Loss: 0.94 Validation Acc: 0.52
# Epoch: 11
# Training Loss: 0.96 Training Acc: 0.55 Validation Loss: 0.94 Validation Acc: 0.51
# Epoch: 12
# Training Loss: 0.94 Training Acc: 0.56 Validation Loss: 0.94 Validation Acc: 0.47
# Epoch: 13
# Training Loss: 0.92 Training Acc: 0.58 Validation Loss: 0.95 Validation Acc: 0.47
# Epoch: 14
# Training Loss: 0.91 Training Acc: 0.57 Validation Loss: 0.94 Validation Acc: 0.52
# Epoch: 15
# Training Loss: 0.89 Training Acc: 0.59 Validation Loss: 0.93 Validation Acc: 0.52
# Epoch: 16
# Training Loss: 0.87 Training Acc: 0.6 Validation Loss: 0.93 Validation Acc: 0.52
# Epoch: 17
# Training Loss: 0.85 Training Acc: 0.64 Validation Loss: 0.87 Validation Acc: 0.5
# Epoch: 18
# Training Loss: 0.83 Training Acc: 0.67 Validation Loss: 0.76 Validation Acc: 0.72
# Epoch: 19
# Training Loss: 0.78 Training Acc: 0.65 Validation Loss: 0.79 Validation Acc: 0.68
# Epoch: 20
# Training Loss: 0.77 Training Acc: 0.66 Validation Loss: 0.86 Validation Acc: 0.61
